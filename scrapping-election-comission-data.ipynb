# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd
import requests
import threading

# %%
def is_url_valid(url):
    r=requests.get(url,verify=False)
    if r.status_code==404:
        return False
    else:
        return True

# %%
# Function to generate URLs and validate them concurrently
def generate_and_validate_urls(urls, url_type, range1, range2, base_url):
    for i in range(1, range1):
        for j in range(1, range2):
            url = f"{base_url}{url_type}{str(i).zfill(2)}{str(j)}"
            if is_url_valid(url):
                urls.append(url)
            else:
                break

# %%
base_url = "https://results.eci.gov.in/PcResultGenJune2024/Constituencywise"
all_urls = []

# Create threads for Union Territories and States
threads = []
threads.append(threading.Thread(target=generate_and_validate_urls, args=(all_urls, 'U', 10, 40, base_url)))
threads.append(threading.Thread(target=generate_and_validate_urls, args=(all_urls, 'S', 30, 80, base_url)))

# Start threads
for thread in threads:
    thread.start()

# Wait for all threads to complete
for thread in threads:
    thread.join()
# Out:
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ...
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\c-ayushi.saigal\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'results.eci.gov.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
print(f"Valid URLs collected: {len(all_urls)}")
if all_urls:
    for url in all_urls:
        print(url)
else:
    print("No valid URLs found.")
# Out:
# Valid URLs collected: 542
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU011
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS011
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS012
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS013
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU021
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS014
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS015
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU031
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS016
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU032
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS017
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS018
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS019
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU051
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0110
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU052
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0111
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU053
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0112
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU054
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0113
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0114
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU055
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0115
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU056
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU057
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0116
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0117
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU061
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0118
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0119
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU071
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0120
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU081
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0121
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU082
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0122
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU083
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0123
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU084
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0124
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU085
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0125
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseU091
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS021
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS022
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS031
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS032
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS033
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS034
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS035
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS036
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS037
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS038
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS039
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0310
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0311
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0312
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0313
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0314
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS041
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS042
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS043
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS044
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS045
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS046
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS047
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS048
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS049
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0410
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0411
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0412
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0413
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0414
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0415
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0416
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0417
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0418
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0419
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0420
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0421
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0422
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0423
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0424
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0425
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0426
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0427
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0428
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0429
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0430
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0431
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0432
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0433
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0434
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0435
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0436
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0437
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0438
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0439
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0440
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS051
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS052
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS061
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS062
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS063
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS064
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS065
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS066
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS067
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS068
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS069
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0610
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0611
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0612
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0613
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0614
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0615
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0616
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0617
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0618
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0619
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0620
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0621
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0622
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0623
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0624
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0625
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0626
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS071
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS072
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS073
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS074
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS075
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS076
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS077
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS078
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS079
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS0710
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS081
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS082
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS083
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS084
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS101
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS102
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS103
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS104
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS105
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS106
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS107
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS108
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS109
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1010
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1011
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1012
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1013
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1014
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1015
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1016
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1017
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1018
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1019
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1020
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1021
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1022
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1023
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1024
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1025
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1026
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1027
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1028
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS111
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS112
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS113
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS114
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS115
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS116
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS117
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS118
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS119
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1110
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1111
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1112
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1113
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1114
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1115
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1116
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1117
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1118
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1119
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1120
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS121
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS122
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS123
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS124
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS125
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS126
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS127
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS128
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS129
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1210
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1211
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1212
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1213
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1214
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1215
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1216
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1217
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1218
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1219
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1220
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1221
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1222
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1223
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1224
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1225
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1226
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1227
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1228
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1229
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS131
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS132
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS133
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS134
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS135
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS136
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS137
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS138
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS139
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1310
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1311
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1312
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1313
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1314
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1315
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1316
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1317
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1318
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1319
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1320
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1321
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1322
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1323
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1324
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1325
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1326
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1327
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1328
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1329
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1330
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1331
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1332
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1333
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1334
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1335
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1336
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1337
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1338
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1339
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1340
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1341
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1342
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1343
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1344
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS1345
# https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS
                columns[5].text,
                columns[6].text,
                state_name,
                constituency_code,
                constituency_name,
                
            )
            
            # Check if the row is already seen
            if row_data not in seen_rows:
                seen_rows.add(row_data)  # Add the row to the set of seen rows
                all_candidate_names.append(columns[1].text)
                all_party_names.append(columns[2].text)
                all_evm_votes.append(columns[3].text)
                all_postal_votes.append(columns[4].text)
                all_total_votes.append(columns[5].text)
                all_percent_votes.append(columns[6].text)
                all_states.append(state_name)
                all_constituency_codes.append(constituency_code)
                all_constituency_names.append(constituency_name)

# Closing the WebDriver
driver.quit()

# Creating a DataFrame from the accumulated data
df = pd.DataFrame({
    'Year' : 2024,
    'Candidate Name': all_candidate_names,
    'State': all_states,
    'Constituency Name': all_constituency_names,
    'Constituency Code': all_constituency_codes,
    'Party Name': all_party_names,
    'EVM Votes': all_evm_votes,
    'Postal Votes': all_postal_votes,
    'Total Votes': all_total_votes,
    'Percent Votes': all_percent_votes,
    

    
    
})

# %%
df.head(5)
# Out:
#    Year      Candidate Name                        State  \
# 0  2024     BISHNU PADA RAY  (Andaman & Nicobar Islands)
# 1  2024  KULDEEP RAI SHARMA  (Andaman & Nicobar Islands)
# 2  2024          MANOJ PAUL  (Andaman & Nicobar Islands)
# 3  2024          D AYYAPPAN  (Andaman & Nicobar Islands)
# 4  2024     V.K. ABDUL AZIZ  (Andaman & Nicobar Islands)
#
#             Constituency Name Constituency Code  \
# 0  Andaman & Nicobar Islands                  1
# 1  Andaman & Nicobar Islands                  1
# 2  Andaman & Nicobar Islands                  1
# 3  Andaman & Nicobar Islands                  1
# 4  Andaman & Nicobar Islands                  1
#
#                             Party Name EVM Votes Postal Votes Total Votes  \
# 0               Bharatiya Janata Party    102182          254      102436
# 1             Indian National Congress     77829          211       78040
# 2  Andaman Nicobar Democratic Congress      8236           18        8254
# 3   Communist Party of India (Marxist)      6009            8        6017
# 4                          Independent      2195            8        2203
#
#   Percent Votes
# 0         50.58
# 1         38.54
# 2          4.08
# 3          2.97
# 4          1.09

# %%
df['State'] = df['State'].str.replace(r'[()]', '', regex=True)

# %%
df.head(5)
# Out:
#    Year      Candidate Name                      State  \
# 0  2024     BISHNU PADA RAY  Andaman & Nicobar Islands
# 1  2024  KULDEEP RAI SHARMA  Andaman & Nicobar Islands
# 2  2024          MANOJ PAUL  Andaman & Nicobar Islands
# 3  2024          D AYYAPPAN  Andaman & Nicobar Islands
# 4  2024     V.K. ABDUL AZIZ  Andaman & Nicobar Islands
#
#             Constituency Name Constituency Code  \
# 0  Andaman & Nicobar Islands                  1
# 1  Andaman & Nicobar Islands                  1
# 2  Andaman & Nicobar Islands                  1
# 3  Andaman & Nicobar Islands                  1
# 4  Andaman & Nicobar Islands                  1
#
#                             Party Name EVM Votes Postal Votes Total Votes  \
# 0               Bharatiya Janata Party    102182          254      102436
# 1             Indian National Congress     77829          211       78040
# 2  Andaman Nicobar Democratic Congress      8236           18        8254
# 3   Communist Party of India (Marxist)      6009            8        6017
# 4                          Independent      2195            8        2203
#
#   Percent Votes
# 0         50.58
# 1         38.54
# 2          4.08
# 3          2.97
# 4          1.09

# %%
df.to_csv("EC_Result.csv", index=False)
